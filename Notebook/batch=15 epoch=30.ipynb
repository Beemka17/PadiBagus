# %% [markdown]
# # **Download Dataset**

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d asheniranga/leaf-disease-dataset-combination
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading leaf-disease-dataset-combination.zip to /content
#  99% 756M/761M [00:09<00:00, 65.7MB/s]
# 100% 761M/761M [00:09<00:00, 84.7MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/leaf-disease-dataset-combination.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# # **Import Library**

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

train_dir = "dataset/train/"
test_dir = "dataset/test/"

# %%
print(train_dir)
print(test_dir)
# Out:
# dataset/train/
# dataset/test/

# %% [markdown]
# # **Data Preparation**

# %%
list(sorted(os.listdir(train_dir)))
# Out:
# ['BrownSpot', 'Healthy', 'Hispa', 'LeafBlast']

# %%
list(sorted(os.listdir(test_dir)))
# Out:
# ['BrownSpot', 'Healthy', 'Hispa', 'LeafBlast']

# %%
batch_size = 15
img_height = 224
img_width = 224

# %%
img_size = (img_height, img_width, 3)

# %%
data_training = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2419 files belonging to 4 classes.

# %%
data_test= tf.keras.utils.image_dataset_from_directory(
  test_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 333 files belonging to 4 classes.

# %%
class_names = data_training.class_names
print(class_names)
# Out:
# ['BrownSpot', 'Healthy', 'Hispa', 'LeafBlast']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in data_training.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in data_training:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (15, 224, 224, 3)
# (15,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

data_train = data_training.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
data_test = data_test.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = data_train.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9575426

# %%
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.5),
  ]
)

# %% [markdown]
# # **Membuat Model**

# %%
print(img_size)
# Out:
# (224, 224, 3)

# %%
MobileNetV3Large  = tf.keras.applications.MobileNetV3Large(input_shape=img_size, include_top=False, weights='imagenet')

MobileNetV3Large.trainable = False

# %%
num_classes = len(class_names)

model = Sequential([
  data_augmentation,
  MobileNetV3Large,
  #layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(filters=32, padding='same', kernel_size=3, activation='relu', strides=1),
  layers.MaxPooling2D(),
  tf.keras.layers.Dropout(rate=0.5),
  #MobileNetV3Small,
  #layers.Conv2D(32, 3, padding='same', activation='relu'),
  #layers.MaxPooling2D(),
  #layers.Conv2D(64, 3, padding='same', activation='relu'),
  #layers.MaxPooling2D(),
  layers.GlobalAveragePooling2D(),
  #layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  MobilenetV3large (Functiona  (None, 7, 7, 960)        2996352
#  l)
#
#  conv2d (Conv2D)             (None, 7, 7, 32)          276512
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 32)         0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 32)          0
#
#  global_average_pooling2d (G  (None, 32)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               4224
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 3,277,604
# Trainable params: 281,252
# Non-trainable params: 2,996,352
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, show_dtype=True, dpi=120)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
epochs=30
history_1 = model.fit(
  data_train,
  validation_data=data_test,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 162/162 [==============================] - 62s 327ms/step - loss: 1.2200 - accuracy: 0.4948 - val_loss: 0.9562 - val_accuracy: 0.6126
# Epoch 2/30
# 162/162 [==============================] - 44s 271ms/step - loss: 1.0533 - accuracy: 0.5754 - val_loss: 0.8854 - val_accuracy: 0.6426
# Epoch 3/30
# 162/162 [==============================] - 44s 269ms/step - loss: 1.0005 - accuracy: 0.5998 - val_loss: 0.8018 - val_accuracy: 0.6877
# Epoch 4/30
# 162/162 [==============================] - 44s 270ms/step - loss: 0.9744 - accuracy: 0.6015 - val_loss: 0.8195 - val_accuracy: 0.6547
# Epoch 5/30
# 162/162 [==============================] - 43s 268ms/step - loss: 0.9434 - accuracy: 0.6151 - val_loss: 0.8093 - val_accuracy: 0.6697
# Epoch 6/30
# 162/162 [==============================] - 44s 269ms/step - loss: 0.9194 - accuracy: 0.6445 - val_loss: 0.7339 - val_accuracy: 0.7087
# Epoch 7/30
# 162/162 [==============================] - 44s 270ms/step - loss: 0.9060 - accuracy: 0.6424 - val_loss: 0.6947 - val_accuracy: 0.7387
# Epoch 8/30
# 162/162 [==============================] - 44s 272ms/step - loss: 0.8990 - accuracy: 0.6445 - val_loss: 0.7453 - val_accuracy: 0.6757
# Epoch 9/30
# 162/162 [==============================] - 44s 269ms/step - loss: 0.8740 - accuracy: 0.6606 - val_loss: 0.6979 - val_accuracy: 0.7147
# Epoch 10/30
# 162/162 [==============================] - 44s 270ms/step - loss: 0.8788 - accuracy: 0.6494 - val_loss: 0.6703 - val_accuracy: 0.7267
# Epoch 11/30
# 162/162 [==============================] - 43s 268ms/step - loss: 0.8626 - accuracy: 0.6623 - val_loss: 0.6889 - val_accuracy: 0.7177
# Epoch 12/30
# 162/162 [==============================] - 44s 272ms/step - loss: 0.8713 - accuracy: 0.6511 - val_loss: 0.7199 - val_accuracy: 0.6967
# Epoch 13/30
# 162/162 [==============================] - 44s 270ms/step - loss: 0.8417 - accuracy: 0.6652 - val_loss: 0.6965 - val_accuracy: 0.6847
# Epoch 14/30
# 162/162 [==============================] - 43s 266ms/step - loss: 0.8373 - accuracy: 0.6685 - val_loss: 0.6369 - val_accuracy: 0.7357
# Epoch 15/30
# 162/162 [==============================] - 44s 270ms/step - loss: 0.8252 - accuracy: 0.6701 - val_loss: 0.6268 - val_accuracy: 0.7387
# Epoch 16/30
# 162/162 [==============================] - 44s 270ms/step - loss: 0.8110 - accuracy: 0.6862 - val_loss: 0.5971 - val_accuracy: 0.7568
# Epoch 17/30
# 162/162 [==============================] - 43s 268ms/step - loss: 0.8053 - accuracy: 0.6780 - val_loss: 0.6490 - val_accuracy: 0.7327
# Epoch 18/30
# 162/162 [==============================] - 44s 269ms/step - loss: 0.8028 - accuracy: 0.6829 - val_loss: 0.5965 - val_accuracy: 0.7718
# Epoch 19/30
# 162/162 [==============================] - 43s 268ms/step - loss: 0.7819 - accuracy: 0.6908 - val_loss: 0.5687 - val_accuracy: 0.7748
# Epoch 20/30
# 162/162 [==============================] - 44s 272ms/step - loss: 0.7975 - accuracy: 0.6796 - val_loss: 0.5960 - val_accuracy: 0.7538
# Epoch 21/30
# 162/162 [==============================] - 44s 269ms/step - loss: 0.7880 - accuracy: 0.6916 - val_loss: 0.6065 - val_accuracy: 0.7688
# Epoch 22/30
# 162/162 [==============================] - 44s 269ms/step - loss: 0.7744 - accuracy: 0.6862 - val_loss: 0.5826 - val_accuracy: 0.7538
# Epoch 23/30
# 162/162 [==============================] - 45s 278ms/step - loss: 0.7630 - accuracy: 0.7040 - val_loss: 0.6191 - val_accuracy: 0.7327
# Epoch 24/30
# 162/162 [==============================] - 45s 276ms/step - loss: 0.7731 - accuracy: 0.6883 - val_loss: 0.5704 - val_accuracy: 0.7868
# Epoch 25/30
# 162/162 [==============================] - 44s 274ms/step - loss: 0.7641 - accuracy: 0.7015 - val_loss: 0.6056 - val_accuracy: 0.7658
# Epoch 26/30
# 162/162 [==============================] - 44s 275ms/step - loss: 0.7699 - accuracy: 0.6966 - val_loss: 0.5564 - val_accuracy: 0.7868
# Epoch 27/30
# 162/162 [==============================] - 45s 275ms/step - loss: 0.7674 - accuracy: 0.7044 - val_loss: 0.5873 - val_accuracy: 0.7688
# Epoch 28/30
# 162/162 [==============================] - 45s 277ms/step - loss: 0.7702 - accuracy: 0.7090 - val_loss: 0.5705 - val_accuracy: 0.7778
# Epoch 29/30
# 162/162 [==============================] - 44s 274ms/step - loss: 0.7651 - accuracy: 0.6982 - val_loss: 0.5629 - val_accuracy: 0.7808
# Epoch 30/30
# 162/162 [==============================] - 45s 276ms/step - loss: 0.7433 - accuracy: 0.7040 - val_loss: 0.5761 - val_accuracy: 0.7718

# %%
acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']

loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # **Testing Model**

# %%
loss, accuracy=model.evaluate(data_test)
print(f"Accuracy:{accuracy}")
print(f"Loss:{loss}")
# Out:
# 23/23 [==============================] - 5s 220ms/step - loss: 0.5761 - accuracy: 0.7718
# Accuracy:0.7717717885971069
# Loss:0.5761420726776123

# %%
x_val=[]
y_val=[]


for image, label in data_test:
    x_val.extend(image.numpy())
    y_val.extend(label.numpy())

# %%
preds=model.predict(np.array(x_val))
y_pred = np.argmax(preds, axis=1)
# Out:
# 11/11 [==============================] - 7s 441ms/step

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,ConfusionMatrixDisplay,classification_report

f1_scores=[]
precision_scores=[]
recall_scores=[]

f1_scores.append(f1_score(y_pred, y_val, average="macro"))
precision_scores.append(precision_score(y_pred, y_val, average="macro"))
recall_scores.append(recall_score(y_pred, y_val, average="macro"))


# Print the Results
print(f"F1-Score:{f1_scores}")
print(f"Precision:{precision_scores}")
print(f"Recall:{recall_scores}")



print("Classification_Report")
print("-----------------------")
print(classification_report(y_val,y_pred))
print("Confusion_Matrix")
print("----------------------")
ConfusionMatrixDisplay.from_predictions(y_val, y_pred, display_labels=class_names, xticks_rotation="vertical")
plt.show()
# Out:
# F1-Score:[0.7323082216434817]
# Precision:[0.7237433174933176]
# Recall:[0.8048561966975141]
# Classification_Report
# -----------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86        52
#            1       0.77      0.87      0.82       148
#            2       0.86      0.34      0.49        56
#            3       0.69      0.86      0.76        77
#
#     accuracy                           0.77       333
#    macro avg       0.80      0.72      0.73       333
# weighted avg       0.79      0.77      0.76       333
#
# Confusion_Matrix
# ----------------------

# %% [markdown]
# # **Percobaan model dengan gambar**

# %%
test_dirr = "leafblast1.jpg"

img = tf.keras.utils.load_img(
    test_dirr, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
im = Image.open(test_dirr)
plt.imshow(im)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 106ms/step
# This image most likely belongs to Leafblast with a 97.54 percent confidence.

# %%
test_dirr = "brownsspot.jpg"

img = tf.keras.utils.load_img(
    test_dirr, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
im = Image.open(test_dirr)
plt.imshow(im)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 990ms/step
# This image most likely belongs to Brownspot with a 99.24 percent confidence.

# %%
test_dirr = "obs2.jpg"

img = tf.keras.utils.load_img(
    test_dirr, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
im = Image.open(test_dirr)
plt.imshow(im)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 89ms/step
# This image most likely belongs to Healthy with a 68.60 percent confidence.

# %%
from tensorflow.keras.models import save_model

save_model(model, 'padi.hdf5')
print("Model Saved")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_withaug)
tflite_model = converter.convert()

with open("modelpadi.tflite", "wb") as f:
  f.write(tflite_model)
